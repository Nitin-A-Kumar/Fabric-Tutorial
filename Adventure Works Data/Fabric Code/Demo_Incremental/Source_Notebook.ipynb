# %%
# %%sql
#
# ALTER TABLE CustomerData
# SET TBLPROPERTIES (delta.enableChangeDataFeed = true);
# Out:
# StatementMeta(, 7f3ab5ce-b384-40c1-9391-ed95c39d9dde, 4, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# DESCRIBE DETAIL CustomerData;
# Out:
# StatementMeta(, 7f3ab5ce-b384-40c1-9391-ed95c39d9dde, 5, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 15 fields>

# %%
spark.sql("ALTER TABLE CustomerData SET TBLPROPERTIES (delta.enableChangeDataFeed = true)")
# Out:
# StatementMeta(, 6f7018f7-ab88-4c89-aeb2-e723c1df89fc, 4, Finished, Available, Finished, False)
# DataFrame[]

# %%
spark.sql("OPTIMIZE CustomerData
VACUUM CustomerData RETAIN 0 HOURS");
# Out:
# StatementMeta(, 1eefbb3a-fc73-4f51-94ee-ca694946e0a5, 3, Finished, Available, Finished, False)
#   Cell In[8], line 1
#     spark.sql("OPTIMIZE CustomerData
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
spark.sql("DESCRIBE DETAIL CustomerData");
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 5, Finished, Available, Finished, False)

# %%
# %%sql
# DESCRIBE DETAIL CustomerData;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 7, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 15 fields>

# %%
# %%sql
#
# ALTER TABLE CustomerData
# SET TBLPROPERTIES (delta.enableChangeDataFeed = true);
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 8, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# DESCRIBE DETAIL CustomerData;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 9, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 15 fields>

# %%
# %%sql
# OPTIMIZE CustomerData;
# VACUUM CustomerData RETAIN 0 HOURS;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 11, Finished, , Finished, True)
# <Spark SQL result set with 1 rows and 2 fields>
# requirement failed: Are you sure you would like to vacuum files with such a low retention period? If you have
# writers that are currently writing to this table, there is a risk that you may corrupt the
# state of your Delta table.
#
# If you are certain that there are no operations being performed on this table, such as
# insert/upsert/delete/optimize, then you may turn off this check by setting:
# spark.databricks.delta.retentionDurationCheck.enabled = false
#
# If you are not sure, please use a value not less than "168 hours".
#
# scala.Predef$.require(Predef.scala:281)
# org.apache.spark.sql.delta.commands.VacuumCommand$.checkRetentionPeriodSafety(VacuumCommand.scala:99)
# org.apache.spark.sql.delta.commands.VacuumCommand$.getValidFilesFromSnapshot(VacuumCommand.scala:118)
# ...

# %%
# %%sql
#
# DESCRIBE DETAIL CustomerData;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 12, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 15 fields>

# %%
# %%sql
#
# ALTER TABLE CustomerData
# SET TBLPROPERTIES (delta.enableChangeDataFeed = true);
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 13, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# DESCRIBE DETAIL Source_lakehouse.dbo.CustomerData;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 16, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 15 fields>

# %%
# %%sql
# ALTER TABLE Source_lakehouse.dbo.CustomerData
# SET TBLPROPERTIES (delta.enableChangeDataFeed = true);
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 20, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# DESCRIBE DETAIL Source_lakehouse.dbo.CustomerData;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 21, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 15 fields>

# %%
# %%sql
#
# CREATE TABLE CustomerData_CDF
# TBLPROPERTIES (delta.enableChangeDataFeed = true)
# AS
# SELECT * FROM CustomerData where CustomerID<>5;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 22, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# DESCRIBE DETAIL Source_lakehouse.dbo.CustomerData_CDF;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 23, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 15 fields>

# %%
# %%sql
# select * from CustomerData_CDF;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 24, Finished, Available, Finished, False)
# <Spark SQL result set with 7 rows and 6 fields>

# %%
# %%sql
#
# INSERT INTO customerdata_cdf
# VALUES (
#     5,
#     'Iii',
#     'Nepal',
#     'Gorakhpur',
#     500,
#     TIMESTAMP '2026-06-16 15:30:00'
# );
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 25, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# select * from CustomerData_CDF;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 26, Finished, Available, Finished, False)
# <Spark SQL result set with 8 rows and 6 fields>

# %%
# %%sql
#
# INSERT INTO customerdata_cdf
# VALUES (
#     5,
#     'Iii',
#     'Nepal',
#     'Kathmandu',
#     500,
#     TIMESTAMP '2026-06-16 15:32:00'
# );
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 27, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# INSERT INTO customerdata_cdf
# VALUES (
#     9,
#     'Rrr',
#     'Australia',
#     'Thane',
#     500,
#     TIMESTAMP '2026-06-16 15:35:00'
# );
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 29, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# select * from CustomerData_CDF;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 30, Finished, Available, Finished, False)
# <Spark SQL result set with 10 rows and 6 fields>

# %%
# %%sql
# delete  from CustomerData_CDF where city ='Kathmandu';
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 31, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# select * from CustomerData_CDF;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 33, Finished, Available, Finished, False)
# <Spark SQL result set with 9 rows and 6 fields>

# %%
# %%sql
# Out:
# StatementMeta(, , -1, Finished, , Finished, True)
# MagicUsageError: Cell magic must contain content.

# %%
# %%sql
# Out:
# StatementMeta(, , -1, Finished, , Finished, True)
# MagicUsageError: Cell magic must contain content.

# %%
# %%sql
# update  customerdata_cdf  set City='Kathmandu',ModifiedDate = TIMESTAMP '2026-06-16 15:58:00'   where CustomerId = 5;
# Out:
# StatementMeta(, 44ea9fa6-ea65-428e-95b0-411c18a30c2f, 40, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
#
# INSERT INTO customerdata_cdf
# VALUES (
#     10,
#     'Rahul',
#     'India',
#     'Mumbai',
#     1000,
#     current_timestamp()
# );
# Out:
# StatementMeta(, fb536aea-e1b3-4ee1-a828-bf2e5623e9c5, 6, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# select * from customerdata_cdf;
# Out:
# StatementMeta(, fb536aea-e1b3-4ee1-a828-bf2e5623e9c5, 14, Finished, Available, Finished, False)
# <Spark SQL result set with 10 rows and 6 fields>

# %%
# %%sql
# update  customerdata_cdf  set City='Pune',ModifiedDate =  current_timestamp()  where CustomerId = 10;
# Out:
# StatementMeta(, 6d9bf1a1-c6ab-4598-8aac-b4aa24354ec7, 2, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
#
# INSERT INTO customerdata_cdf
# VALUES (
#     11,
#     'Nakshit',
#     'UK',
#     'London',
#     80000,
#     current_timestamp()
# );

# %%
# %%sql
# delete  from CustomerData_CDF where city ='Mumbai' and customerid=10;
# Out:
# StatementMeta(, fb536aea-e1b3-4ee1-a828-bf2e5623e9c5, 11, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 1 fields>
