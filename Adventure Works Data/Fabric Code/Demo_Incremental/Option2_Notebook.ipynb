# %%
# Incremental Load

# %%
# %%sql
# CREATE TABLE Sales (
#     SalesID INT,
#     ProductID INT,
#     Quantity INT,
#     Amount DECIMAL(10,2),
#     ModifiedDate TIMESTAMP
# )
# TBLPROPERTIES (
#     'delta.enableChangeDataFeed' = 'true'
# );
# Out:
# StatementMeta(, dab843f1-a75d-4927-9768-dc9bdde0fcc2, 5, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# INSERT INTO Sales
# VALUES
# (1,101,25,500,'2026-06-01 10:00:00'),
# (2,102,6,300,'2026-06-05 11:00:00'),
# (3,103,12,1200,'2026-06-10 09:30:00');
# Out:
# StatementMeta(, dab843f1-a75d-4927-9768-dc9bdde0fcc2, 6, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# INSERT INTO Sales
# VALUES
# (2,102,6,999,'2026-06-16 11:00:00');
# Out:
# StatementMeta(, 544760d0-f67f-473e-a9df-9e987f072624, 2, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# select * from sales;
# Out:
# StatementMeta(, 544760d0-f67f-473e-a9df-9e987f072624, 3, Finished, Available, Finished, False)
# <Spark SQL result set with 5 rows and 5 fields>

# %%
# Out:
# StatementMeta(, 77603a2f-bd26-49b9-94aa-d18ffd91e6ac, 2, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>
