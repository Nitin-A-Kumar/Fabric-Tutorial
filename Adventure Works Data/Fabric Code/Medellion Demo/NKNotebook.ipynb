# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
print("Welcom  Nitin ")
# Out:
# StatementMeta(, dd7b5815-552e-437b-be7c-d3fb92295a43, 3, Finished, Available, Finished, False)
# Welcom  Nitin

# %% [markdown]
# %%html
# # Data Engineering Hand-On

# %%
df = spark.read.format("csv").option("header","true").load("Files/BronzeRawData_Retuned/Bronze_Returns.csv")
# df now is a Spark DataFrame containing CSV data from "Files/BronzeRawData_Retuned/Bronze_Returns.csv".
display(df)
# Out:
# StatementMeta(, 91b3a16c-61b7-4234-b013-3276854549b0, 8, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, fa8b2314-e287-4f86-a05f-99755aac7936)

# %%
df = spark.read.format("csv").option("header","true").load("abfss://NitinFabricWS@onelake.dfs.fabric.microsoft.com/bronzeLakehouse.Lakehouse/Files/BronzeRawData_Retuned")
# df now is a Spark DataFrame containing CSV data from "Files/BronzeRawData_Retuned/Bronze_Returns.csv".
display(df)
# Out:
# StatementMeta(, 91b3a16c-61b7-4234-b013-3276854549b0, 9, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 90c4e6cb-14e5-43b3-9c46-2471e1482b0f)

# %%
df = spark.sql("select * from returns limit 100")
display(df)
# Out:
# StatementMeta(, 91b3a16c-61b7-4234-b013-3276854549b0, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 17efa046-c39f-4267-8f51-6b3d23c016f6)
